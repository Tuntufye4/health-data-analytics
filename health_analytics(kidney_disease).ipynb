# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("kidney_disease.csv")
data.head()
# Out:
#    id   age    bp  specific_gravity  albumin  sugar red_blood_cell_count  \
# 0   0  48.0  80.0             1.020      1.0    0.0                  NaN
# 1   1   7.0  50.0             1.020      4.0    0.0                  NaN
# 2   2  62.0  80.0             1.010      2.0    3.0               normal
# 3   3  48.0  70.0             1.005      4.0    0.0               normal
# 4   4  51.0  80.0             1.010      2.0    0.0               normal
#
#   pus_cells pathological_casts          ba  ...  Packed_Cell_Volume  \
# 0    normal         notpresent  notpresent  ...                  44
# 1    normal         notpresent  notpresent  ...                  38
# 2    normal         notpresent  notpresent  ...                  31
# 3  abnormal            present  notpresent  ...                  32
# 4    normal         notpresent  notpresent  ...                  35
#
#    White_Blood_Cell_Count   Red_Blood_Cell_Count  htn  Diabetes_Mellitus  \
# 0                    7800                    5.2  yes                yes
# 1                    6000                    NaN   no                 no
# 2                    7500                    NaN   no                yes
# 3                    6700                    3.9  yes                 no
# 4                    7300                    4.6   no                 no
#
#    Coronary_Artery_Disease  Appetite Pedal_Edema Anemia classification
# 0                       no      good          no     no            ckd
# 1                       no      good          no     no            ckd
# 2                       no      poor          no    yes            ckd
# 3                       no      poor         yes    yes            ckd
# 4                       no      good          no     no            ckd
#
# [5 rows x 26 columns]

# %%
# summary statistics

data.describe()
# Out:
#                id         age          bp  specific_gravity     albumin  \
# count  400.000000  391.000000  388.000000        353.000000  354.000000
# mean   199.500000   51.483376   76.469072          1.017408    1.016949
# std    115.614301   17.169714   13.683637          0.005717    1.352679
# min      0.000000    2.000000   50.000000          1.005000    0.000000
# 25%     99.750000   42.000000   70.000000          1.010000    0.000000
# 50%    199.500000   55.000000   80.000000          1.020000    0.000000
# 75%    299.250000   64.500000   80.000000          1.020000    2.000000
# max    399.000000   90.000000  180.000000          1.025000    5.000000
#
#             sugar  Blood_Glucose_Random   Blood_Urea  Serum_Creatinine  \
# count  351.000000            356.000000   381.000000        383.000000
# mean     0.450142            148.036517    57.425722          3.072454
# std      1.099191             79.281714    50.503006          5.741126
# min      0.000000             22.000000     1.500000          0.400000
# 25%      0.000000             99.000000    27.000000          0.900000
# 50%      0.000000            121.000000    42.000000          1.300000
# 75%      0.000000            163.000000    66.000000          2.800000
# max      5.000000            490.000000   391.000000         76.000000
#
#            Sodium   Potassium  Hemoglobin
# count  313.000000  312.000000  348.000000
# mean   137.528754    4.627244   12.526437
# std     10.408752    3.193904    2.912587
# min      4.500000    2.500000    3.100000
# 25%    135.000000    3.800000   10.300000
# 50%    138.000000    4.400000   12.650000
# 75%    142.000000    4.900000   15.000000
# max    163.000000   47.000000   17.800000

# %%
# display all the column names in the data

data.columns
# Out:
# Index(['id', 'age', 'bp', 'specific_gravity', 'albumin', 'sugar',
#        'red_blood_cell_count', 'pus_cells', 'pathological_casts', 'ba',
#        'Blood_Glucose_Random', ' Blood_Urea', 'Serum_Creatinine', 'Sodium',
#        'Potassium', 'Hemoglobin', 'Packed_Cell_Volume',
#        'White_Blood_Cell_Count', ' Red_Blood_Cell_Count', 'htn',
#        'Diabetes_Mellitus', 'Coronary_Artery_Disease', ' Appetite',
#        'Pedal_Edema', 'Anemia', 'classification'],
#       dtype='object')

# %%
# Display the counts of each value in the bp column

data['bp'].value_counts()
# Out:
# 80.0     116
# 70.0     112
# 60.0      71
# 90.0      53
# 100.0     25
# 50.0       5
# 110.0      3
# 140.0      1
# 180.0      1
# 120.0      1
# Name: bp, dtype: int64

# %%
# plot the value counts of bp 
data['bp'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# Display the counts of each value in the sugar column

data['sugar'].value_counts()
# Out:
# 0.0    290
# 2.0     18
# 3.0     14
# 4.0     13
# 1.0     13
# 5.0      3
# Name: sugar, dtype: int64

# %%
# plot the value counts of sugar 
data['sugar'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
# plot the value counts of classification (chronical kidney disease or not) 
data['classification'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>
# c:\users\tuntu\appdata\local\programs\python\python38\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 9 (	) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# mean, median and mode of the age distribution
print("Mean: {}".format(data['age'].mean()))
print("Median: {}".format(data['age'].median()))
print("Mode: {}".format(data['age'].mode()))
# Out:
# Mean: 51.48337595907928
# Median: 55.0
# Mode: 0    60.0
# Name: age, dtype: float64

# %%
# top 10 ages
data['age'].value_counts().head(10)
# Out:
# 60.0    19
# 65.0    17
# 48.0    12
# 55.0    12
# 50.0    12
# 47.0    11
# 62.0    10
# 56.0    10
# 59.0    10
# 54.0    10
# Name: age, dtype: int64

# %%
# better looking boxplot (using seaborn) for age variable
sns.boxplot(data['age'])
# Out:
# c:\users\tuntu\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
# subset involving only records of normal pus cells
data[data['pus_cells']=='normal'].head()
# Out:
#    id   age    bp  specific_gravity  albumin  sugar red_blood_cell_count  \
# 0   0  48.0  80.0              1.02      1.0    0.0                  NaN
# 1   1   7.0  50.0              1.02      4.0    0.0                  NaN
# 2   2  62.0  80.0              1.01      2.0    3.0               normal
# 4   4  51.0  80.0              1.01      2.0    0.0               normal
# 6   6  68.0  70.0              1.01      0.0    0.0                  NaN
#
#   pus_cells pathological_casts          ba  ...  Packed_Cell_Volume  \
# 0    normal         notpresent  notpresent  ...                  44
# 1    normal         notpresent  notpresent  ...                  38
# 2    normal         notpresent  notpresent  ...                  31
# 4    normal         notpresent  notpresent  ...                  35
# 6    normal         notpresent  notpresent  ...                  36
#
#    White_Blood_Cell_Count   Red_Blood_Cell_Count  htn  Diabetes_Mellitus  \
# 0                    7800                    5.2  yes                yes
# 1                    6000                    NaN   no                 no
# 2                    7500                    NaN   no                yes
# 4                    7300                    4.6   no                 no
# 6                     NaN                    NaN   no                 no
#
#    Coronary_Artery_Disease  Appetite Pedal_Edema Anemia classification
# 0                       no      good          no     no            ckd
# 1                       no      good          no     no            ckd
# 2                       no      poor          no    yes            ckd
# 4                       no      good          no     no            ckd
# 6                       no      good          no     no            ckd
#
# [5 rows x 26 columns]

# %%
# subset involving only records of abnormal pus cells
data[data['pus_cells']=='abnormal'].head()
# Out:
#     id   age     bp  specific_gravity  albumin  sugar red_blood_cell_count  \
# 3    3  48.0   70.0             1.005      4.0    0.0               normal
# 7    7  24.0    NaN             1.015      2.0    4.0               normal
# 8    8  52.0  100.0             1.015      3.0    0.0               normal
# 9    9  53.0   90.0             1.020      2.0    0.0             abnormal
# 10  10  50.0   60.0             1.010      2.0    4.0                  NaN
#
#    pus_cells pathological_casts          ba  ...  Packed_Cell_Volume  \
# 3   abnormal            present  notpresent  ...                  32
# 7   abnormal         notpresent  notpresent  ...                  44
# 8   abnormal            present  notpresent  ...                  33
# 9   abnormal            present  notpresent  ...                  29
# 10  abnormal            present  notpresent  ...                  28
#
#     White_Blood_Cell_Count   Red_Blood_Cell_Count  htn  Diabetes_Mellitus  \
# 3                     6700                    3.9  yes                 no
# 7                     6900                      5   no                yes
# 8                     9600                      4  yes                yes
# 9                    12100                    3.7  yes                yes
# 10                     NaN                    NaN  yes                yes
#
#     Coronary_Artery_Disease  Appetite Pedal_Edema Anemia classification
# 3                        no      poor         yes    yes            ckd
# 7                        no      good         yes     no            ckd
# 8                        no      good          no    yes            ckd
# 9                        no      poor          no    yes            ckd
# 10                       no      good          no    yes            ckd
#
# [5 rows x 26 columns]

# %%
# Most common bp by age
for i in data['age'].unique():
    print("Age: {} Count: {}".format(i,data[data['age']==i]['bp'].value_counts().head(1)))
# Out:
# Age: 48.0 Count: 80.0    6
# Name: bp, dtype: int64
# Age: 7.0 Count: 50.0    1
# Name: bp, dtype: int64
# Age: 62.0 Count: 80.0    5
# Name: bp, dtype: int64
# Age: 51.0 Count: 80.0    2
# Name: bp, dtype: int64
# Age: 60.0 Count: 90.0    5
# Name: bp, dtype: int64
# Age: 68.0 Count: 70.0    4
# Name: bp, dtype: int64
# Age: 24.0 Count: 80.0    2
# Name: bp, dtype: int64
# Age: 52.0 Count: 80.0    3
# Name: bp, dtype: int64
# Age: 53.0 Count: 90.0    2
# Name: bp, dtype: int64
# Age: 50.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 63.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 40.0 Count: 80.0    3
# Name: bp, dtype: int64
# Age: 47.0 Count: 80.0    5
# Name: bp, dtype: int64
# Age: 61.0 Count: 80.0    3
# Name: bp, dtype: int64
# Age: 21.0 Count: 70.0    1
# Name: bp, dtype: int64
# Age: 42.0 Count: 80.0    2
# Name: bp, dtype: int64
# Age: 75.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 69.0 Count: 70.0    4
# Name: bp, dtype: int64
# Age: nan Count: Series([], Name: bp, dtype: int64)
# Age: 73.0 Count: 90.0    2
# Name: bp, dtype: int64
# Age: 70.0 Count: 70.0    2
# Name: bp, dtype: int64
# Age: 65.0 Count: 70.0    6
# Name: bp, dtype: int64
# Age: 76.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 72.0 Count: 90.0    4
# Name: bp, dtype: int64
# Age: 82.0 Count: 80.0    1
# Name: bp, dtype: int64
# Age: 46.0 Count: 60.0    3
# Name: bp, dtype: int64
# Age: 45.0 Count: 80.0    4
# Name: bp, dtype: int64
# Age: 35.0 Count: 80.0    3
# Name: bp, dtype: int64
# Age: 54.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 11.0 Count: 80.0    1
# Name: bp, dtype: int64
# Age: 59.0 Count: 70.0    4
# Name: bp, dtype: int64
# Age: 67.0 Count: 80.0    3
# Name: bp, dtype: int64
# Age: 15.0 Count: 60.0    1
# Name: bp, dtype: int64
# Age: 55.0 Count: 80.0    7
# Name: bp, dtype: int64
# Age: 44.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 26.0 Count: 70.0    1
# Name: bp, dtype: int64
# Age: 64.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 56.0 Count: 90.0    3
# Name: bp, dtype: int64
# Age: 5.0 Count: 50.0    1
# Name: bp, dtype: int64
# Age: 74.0 Count: 60.0    2
# Name: bp, dtype: int64
# Age: 38.0 Count: 70.0    1
# Name: bp, dtype: int64
# Age: 58.0 Count: 70.0    2
# Name: bp, dtype: int64
# Age: 71.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 34.0 Count: 70.0    5
# Name: bp, dtype: int64
# Age: 17.0 Count: 60.0    2
# Name: bp, dtype: int64
# Age: 12.0 Count: 60.0    1
# Name: bp, dtype: int64
# Age: 43.0 Count: 80.0    4
# Name: bp, dtype: int64
# Age: 41.0 Count: 80.0    3
# Name: bp, dtype: int64
# Age: 57.0 Count: 80.0    4
# Name: bp, dtype: int64
# Age: 8.0 Count: 60.0    1
# Name: bp, dtype: int64
# Age: 39.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 66.0 Count: 70.0    4
# Name: bp, dtype: int64
# Age: 81.0 Count: 60.0    1
# Name: bp, dtype: int64
# Age: 14.0 Count: Series([], Name: bp, dtype: int64)
# Age: 27.0 Count: 60.0    1
# Name: bp, dtype: int64
# Age: 83.0 Count: 70.0    1
# Name: bp, dtype: int64
# Age: 30.0 Count: 80.0    4
# Name: bp, dtype: int64
# Age: 4.0 Count: Series([], Name: bp, dtype: int64)
# Age: 3.0 Count: Series([], Name: bp, dtype: int64)
# Age: 6.0 Count: 60.0    1
# Name: bp, dtype: int64
# Age: 32.0 Count: 90.0    1
# Name: bp, dtype: int64
# Age: 80.0 Count: 70.0    3
# Name: bp, dtype: int64
# Age: 49.0 Count: 100.0    1
# Name: bp, dtype: int64
# Age: 90.0 Count: 90.0    1
# Name: bp, dtype: int64
# Age: 78.0 Count: 60.0    1
# Name: bp, dtype: int64
# Age: 19.0 Count: 70.0    1
# Name: bp, dtype: int64
# Age: 2.0 Count: Series([], Name: bp, dtype: int64)
# Age: 33.0 Count: 80.0    3
# Name: bp, dtype: int64
# Age: 36.0 Count: 80.0    2
# Name: bp, dtype: int64
# Age: 37.0 Count: 60.0    2
# Name: bp, dtype: int64
# Age: 23.0 Count: 80.0    3
# Name: bp, dtype: int64
# Age: 25.0 Count: 80.0    1
# Name: bp, dtype: int64
# Age: 20.0 Count: 60.0    1
# Name: bp, dtype: int64
# Age: 29.0 Count: 80.0    2
# Name: bp, dtype: int64
# Age: 28.0 Count: 70.0    1
# Name: bp, dtype: int64
# Age: 22.0 Count: 60.0    1
# Name: bp, dtype: int64
# Age: 79.0 Count: 80.0    1
# Name: bp, dtype: int64

# %%
# group by classification to get mean statistics
data.groupby('classification').mean()
# Out:
#                         id        age         bp  specific_gravity   albumin  \
# classification
# ckd             124.427419  54.425000  79.705882          1.013937  1.721154
# ckd\t           133.500000  68.500000  70.000000          1.010000  2.000000
# notckd          324.500000  46.516779  71.351351          1.022414  0.000000
#
#                    sugar  Blood_Glucose_Random   Blood_Urea  Serum_Creatinine  \
# classification
# ckd             0.770732            175.523810    72.656170          4.430720
# ckd\t           0.000000            164.500000    41.000000          2.550000
# notckd          0.000000            107.722222    32.798611          0.868966
#
#                     Sodium  Potassium  Hemoglobin
# classification
# ckd             133.882530   4.883030   10.652217
# ckd\t           135.500000   4.500000    9.700000
# notckd          141.731034   4.337931   15.188194
